# %%
import pandas as pd
import re
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib

#### load using pandas
d = pd.read_csv('data_2d.csv', header=None)
arr = d.as_matrix()
X = d[[0,1]].as_matrix()
Y = d[[2]].as_matrix()

##### parse manually
# X = []
# Y = []
# for line in open('data_2d.csv'):
#     x1, x2, y = line.split(',')
#     X.append([float(x1), float(x2), 1]) # add the bias term
#     Y.append(float(y))

# X = np.array(X)
# Y = np.array(Y)

##### plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.scatter(X2[:,0], X2[:,1], Y2)
# plt.show()


print()
A = np.dot(X, X.T)
B = np.dot(X.T, Y)
w = np.linalg.solve(A,B)
Yhat = X.dot(W) 

d1 = Y - Yhat
d2 = Y - Y.mean()
r2 = 1-d1.dot(d1) / d2.dot(d2)
print(r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6988fb238671> in <module>()
#      32 A = np.dot(X, X.T)
#      33 B = np.dot(X.T, Y)
# ---> 34 w = np.linalg.solve(A,B)
#      35 Yhat = X.dot(W)
#      36
#
# /usr/local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in solve(a, b)
#     373     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     374     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 375     r = gufunc(a, b, signature=signature, extobj=extobj)
#     376
#     377     return wrap(r.astype(result_t, copy=False))
#
# ValueError: solve: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (m,m),(m,n)->(m,n) (size 2 is different from 100)

# %%
X = []
Y = []
for line in open('data_2d.csv'):
    x1, x2, y = line.split(',')
    X.append([float(x1), float(x2), 1]) # add the bias term
    Y.append(float(y))

# let's turn X and Y into numpy arrays since that will be useful later
X = np.array(X)
Y = np.array(Y)


# let's plot the data to see what it looks like
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)
plt.show()

# %%
a.shape[-2:]
# Out:
# (3, 2)

# %%
a = np.array([[3,1], [1,2], [5,3]])
b = np.array([9,8,2])
x = np.linalg.solve(a, b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-46-dd67604496aa> in <module>()
#       1 a = np.array([[3,1], [1,2], [5,3]])
#       2 b = np.array([9,8,2])
# ----> 3 x = np.linalg.solve(a, b)
#
# /usr/local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in solve(a, b)
#     360     a, _ = _makearray(a)
#     361     _assertRankAtLeast2(a)
# --> 362     _assertNdSquareness(a)
#     363     b, wrap = _makearray(b)
#     364     t, result_t = _commonType(a, b)
#
# /usr/local/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _assertNdSquareness(*arrays)
#     210     for a in arrays:
#     211         if max(a.shape[-2:]) != min(a.shape[-2:]):
# --> 212             raise LinAlgError('Last 2 dimensions of the array must be square')
#     213
#     214 def _assertFinite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square
